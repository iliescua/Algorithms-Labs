# %%
import jumpSearch as js
import matplotlib.pyplot as plt
import numpy as np
import random as rand
import time

# %%
def benchmark(lst, val):
    times = [] #Used to store the duration time
    n_trials = 10 #Number of trials for each list
    for i in range(n_trials):
        copy = lst[:] #Duplicate list was made so that the order isn't altered
        start = time.clock()
        loc = js.jump(copy, val)
        end = time.clock()
        elapsed = end - start
        times.append(elapsed)
    avg = np.mean(times) #Calculates the average run time
    if loc != None:
        print("Found at: " + str(int(loc)))
    else:
        print("Not Found") 
    return avg

# %%
def plotJump(trials, results):
    #Creates a plot to show how size affects runtime 
    plt.plot(np.log10(trials), results)
    plt.xlabel("List Size (log10)", fontsize=12)
    plt.ylabel("Running Time (s)", fontsize=12)
    plt.title("Jump Search: List Size vs. Run Time", fontsize=14)
    plt.show()

# %%
trials = [100, 1000, 10000, 100000] #List Sizes
lst = [] 
results = []
val = 13 #Random value to check for to see if it exists in the list

for length in trials: #Iterates so long as there are more lists to do
    lst = [rand.randint(1, 100) for i in range(length)] #Creates a list of random values
    
    #Sorted List Smallest->Largest
    lst.sort()
    results.append(benchmark(lst, val)) #Calls the benchmark and stores average time

plotJump(trials, results)
# Out:
# Not Found
# Found at: 105
# Found at: 1233
# Found at: 12175
